# %%
import pandas as pd
df=pd.read_csv("pmsm_temperature_data.csv")
df.head()
# Out:
#     ambient   coolant       u_d       u_q  motor_speed    torque       i_d  \
# 0 -0.752143 -1.118446  0.327935 -1.297858    -1.222428 -0.250182  1.029572
# 1 -0.771263 -1.117021  0.329665 -1.297686    -1.222429 -0.249133  1.029509
# 2 -0.782892 -1.116681  0.332771 -1.301822    -1.222428 -0.249431  1.029448
# 3 -0.780935 -1.116764  0.333700 -1.301852    -1.222430 -0.248636  1.032845
# 4 -0.774043 -1.116775  0.335206 -1.303118    -1.222429 -0.248701  1.031807
#
#         i_q        pm  stator_yoke  stator_tooth  stator_winding  profile_id
# 0 -0.245860 -2.522071    -1.831422     -2.066143       -2.018033           4
# 1 -0.245832 -2.522418    -1.830969     -2.064859       -2.017631           4
# 2 -0.245818 -2.522673    -1.830400     -2.064073       -2.017343           4
# 3 -0.246955 -2.521639    -1.830333     -2.063137       -2.017632           4
# 4 -0.246610 -2.521900    -1.830498     -2.062795       -2.018145           4

# %%
data=df.drop('profile_id',axis=1)

# %%
data
# Out:
#          ambient   coolant       u_d       u_q  motor_speed    torque  \
# 0      -0.752143 -1.118446  0.327935 -1.297858    -1.222428 -0.250182
# 1      -0.771263 -1.117021  0.329665 -1.297686    -1.222429 -0.249133
# 2      -0.782892 -1.116681  0.332771 -1.301822    -1.222428 -0.249431
# 3      -0.780935 -1.116764  0.333700 -1.301852    -1.222430 -0.248636
# 4      -0.774043 -1.116775  0.335206 -1.303118    -1.222429 -0.248701
# 5      -0.762936 -1.116955  0.334901 -1.303017    -1.222429 -0.248197
# 6      -0.749228 -1.116170  0.335014 -1.302082    -1.222430 -0.247914
# 7      -0.738450 -1.113986  0.336256 -1.305155    -1.222432 -0.248321
# 8      -0.730910 -1.111828  0.334905 -1.303790    -1.222432 -0.247785
# 9      -0.727130 -1.109486  0.335988 -1.305633    -1.222431 -0.248294
# 10     -0.723713 -1.108284  0.335400 -1.304560    -1.222428 -0.247913
# 11     -0.717754 -1.108588  0.334431 -1.304337    -1.222429 -0.247721
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          ambient   coolant       u_d       u_q  motor_speed    torque  \
# 0      -0.752143 -1.118446  0.327935 -1.297858    -1.222428 -0.250182
# 1      -0.771263 -1.117021  0.329665 -1.297686    -1.222429 -0.249133
# 2      -0.782892 -1.116681  0.332771 -1.301822    -1.222428 -0.249431
# 3      -0.780935 -1.116764  0.333700 -1.301852    -1.222430 -0.248636
# 4      -0.774043 -1.116775  0.335206 -1.303118    -1.222429 -0.248701
# 5      -0.762936 -1.116955  0.334901 -1.303017    -1.222429 -0.248197
# 6      -0.749228 -1.116170  0.335014 -1.302082    -1.222430 -0.247914
# 7      -0.738450 -1.113986  0.336256 -1.305155    -1.222432 -0.248321
# 8      -0.730910 -1.111828  0.334905 -1.303790    -1.222432 -0.247785
# 9      -0.727130 -1.109486  0.335988 -1.305633    -1.222431 -0.248294
# 10     -0.723713 -1.108284  0.335400 -1.304560    -1.222428 -0.247913
# 11     -0.717754 -1.108588  0.334431 -1.304337    -1.222429 -0.247721
# ...

# %%
data.shape
# Out:
# (998070, 12)

# %%
import sklearn as sk
from sklearn.preprocessing import scale
uni_norm=scale(data)
type(uni_norm)
# Out:
# numpy.ndarray

# %%
uni_norm = pd.DataFrame(uni_norm)
uni_norm.head()
type(uni_norm)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.decomposition import PCA
import sklearn as sk 
sk.preprocessing.scale
# Out:
# <function sklearn.preprocessing.data.scale(X, axis=0, with_mean=True, with_std=True, copy=True)>

# %%
pcs=PCA()
pca_values=pcs.fit_transform(data)

# %%
type(pca_values)
# Out:
# numpy.ndarray

# %%
var=pcs.explained_variance_ratio_
var
# Out:
# array([3.81665619e-01, 2.60193898e-01, 1.52067541e-01, 7.38499672e-02,
#        6.04740092e-02, 3.26557730e-02, 2.21064447e-02, 1.26538558e-02,
#        3.42282484e-03, 6.72095340e-04, 1.69302244e-04, 6.86692269e-05])

# %%
pccomp = pd.DataFrame(pcs.components_)
pccomp
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.245984 -0.328831  0.014926 -0.121341 -0.215937  0.042694  0.202766
# 1  -0.190043 -0.183684 -0.503977  0.084178  0.210999  0.511579 -0.306494
# 2  -0.045870 -0.281173  0.129675  0.523573  0.576758 -0.258437 -0.321992
# 3  -0.243110 -0.317132  0.078197 -0.648021 -0.048912 -0.169880 -0.508266
# 4  -0.814233  0.285451  0.145479  0.138865  0.003857 -0.035188  0.039163
# 5  -0.366318 -0.370992 -0.088672  0.157863 -0.081453 -0.057939  0.461771
# 6   0.139025 -0.395285  0.640157  0.211912 -0.245575  0.234018 -0.012450
# 7   0.151194 -0.332363 -0.512558  0.109374 -0.181495 -0.216198  0.196381
# 8  -0.052826  0.111580 -0.137868  0.427331 -0.687120 -0.066913 -0.489893
# 9  -0.004828 -0.405712  0.006752 -0.019796 -0.017402 -0.024950 -0.091411
# 10 -0.001679  0.022967 -0.046726 -0.004555 -0.014609 -0.726739 -0.024590
# 11  0.000709 -0.122829 -0.008603 -0.005731  0.035516 -0.038264  0.022161
#
# ...

# %%
np.round(var*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2607e7cf7ba3> in <module>
# ----> 1 np.round(var*100)
#
# NameError: name 'np' is not defined

# %%
import numpy as np
cumvar = np.cumsum(np.round(var,decimals = 4)*100)
cumvar
# Out:
# array([ 38.17,  64.19,  79.4 ,  86.78,  92.83,  96.1 ,  98.31,  99.58,
#         99.92,  99.99, 100.01, 100.02])

# %%
from matplotlib import pyplot as plt
plt.plot(cumvar,color="red")
plt.show()

# %%
pcs=pd.DataFrame(pca_values)
pcs
# Out:
#               0         1         2         3         4         5         6   \
# 0       4.721587 -0.891012 -0.402894  0.294536  0.057942 -0.834861 -0.184410
# 1       4.725043 -0.887884 -0.402596  0.298699  0.074632 -0.828739 -0.185840
# 2       4.727687 -0.887765 -0.404029  0.304451  0.084461 -0.825673 -0.186290
# 3       4.727192 -0.889806 -0.405126  0.302586  0.082881 -0.824128 -0.185679
# 4       4.725716 -0.891556 -0.405612  0.302211  0.077295 -0.827655 -0.184001
# 5       4.723421 -0.892709 -0.405750  0.299915  0.067984 -0.832088 -0.182136
# 6       4.719720 -0.894885 -0.405895  0.296169  0.057197 -0.837610 -0.179768
# 7       4.716324 -0.898297 -0.408430  0.295081  0.049110 -0.843369 -0.178983
# 8       4.713716 -0.899060 -0.408956  0.291391  0.043515 -0.846841 -0.179507
# 9       4.712216 -0.901110 -0.410458  0.291095  0.040956 -0.849501 -0.179851
# 10      4.710514 -0.901269 -0.410582  0.289271  0.038644 -0.850969 -0.179686
# ...

# %%
new_df=pd.DataFrame(pca_values[:1000,:5]).values

# %%
new_df
type(new_df)
# Out:
# numpy.ndarray

# %%
df=pd.DataFrame(new_df)

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=0)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
wcss
# Out:
# [1173.9399822090788,
#  608.0622625074948,
#  206.69199625506576,
#  119.30237343381614,
#  62.71048216952165,
#  42.86742204396968,
#  33.22152465560051,
#  25.16133009040439,
#  20.290027229653465,
#  17.01579661280028]

# %%
from matplotlib import pyplot as plt
plt.plot(range(1,11),wcss)
plt.show()

# %%
kmeans=KMeans(n_clusters=3,init='k-means++',random_state=0)
y_means=kmeans.fit_predict(df)
C=kmeans.cluster_centers_

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax=Axes3D(fig)
ax.scatter()
