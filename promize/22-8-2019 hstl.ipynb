# %%
import pandas as pd
df=pd.read_csv("stock_data.csv")

# %%
df.head()
# Out:
#            X1          X2          X3          X4          X5          X6  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   91.567862   96.621901   98.084599   96.543909   91.678881   96.337918
# 2   92.908600   97.640753  103.112398   98.130312   78.041958   97.693843
# 3   84.869178   94.369892  109.018217  102.209632   73.357203  100.676878
# 4   88.888889   95.603221  108.459686  103.116147   77.832727  104.677398
#
#          X7          X8          X9         X10 ...         X92         X93  \
# 0  100.0000  100.000000  100.000000  100.000000 ...  100.000000  100.000000
# 1   96.1250   94.015957   94.409201   97.084183 ...   96.888889   95.499022
# 2   95.6250   95.744681   94.089712   96.655229 ...   97.333333   96.379804
# 3   96.9166   93.085106   98.243067   98.113343 ...  101.925926   95.988415
# 4  100.8750   93.617021  100.000000   99.828542 ...  102.074074  102.152642
#
# ...

# %%
df.head()
# Out:
#            X1          X2          X3          X4          X5          X6  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   91.567862   96.621901   98.084599   96.543909   91.678881   96.337918
# 2   92.908600   97.640753  103.112398   98.130312   78.041958   97.693843
# 3   84.869178   94.369892  109.018217  102.209632   73.357203  100.676878
# 4   88.888889   95.603221  108.459686  103.116147   77.832727  104.677398
#
#          X7          X8          X9         X10 ...         X92         X93  \
# 0  100.0000  100.000000  100.000000  100.000000 ...  100.000000  100.000000
# 1   96.1250   94.015957   94.409201   97.084183 ...   96.888889   95.499022
# 2   95.6250   95.744681   94.089712   96.655229 ...   97.333333   96.379804
# 3   96.9166   93.085106   98.243067   98.113343 ...  101.925926   95.988415
# 4  100.8750   93.617021  100.000000   99.828542 ...  102.074074  102.152642
#
# ...

# %%
import sklearn as sk
from sklearn.preprocessing import scale

# %%
uni_norm=scale(df)
# Out:
# C:\Users\GANESHBABU\Anaconda3\include\New folder\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
#   """Entry point for launching an IPython kernel.

# %%
uni_norm
# Out:
# array([[-0.64853976,  5.83947042, -1.06861533, ..., -0.56167634,
#          5.94033244,  1.00534763],
#        [-0.67325075,  5.45958853, -1.11087739, ..., -0.5715271 ,
#          5.43951518, -0.99468081],
#        [-0.66932163,  5.57416282, -0.99994232, ..., -0.58137786,
#          4.93087265,  1.00534763],
#        ...,
#        [ 2.55649976, -0.46255934,  1.24699009, ...,  1.81804018,
#         -0.56152768, -0.99468081],
#        [ 2.5735724 , -0.38923797,  1.31066492, ...,  1.83319519,
#         -0.55213736,  1.00534763],
#        [ 2.6527414 , -0.38537895,  1.34785552, ...,  1.90612871,
#         -0.52584445, -0.99468081]])

# %%
df1=pd.DataFrame(uni_norm)
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
pcs=PCA()
pca_values=pcs.fit_transform(df1)

# %%
type(pca_values)
# Out:
# numpy.ndarray

# %%
var=pcs.explained_variance_ratio_
var
# Out:
# array([4.99265283e-01, 1.72695693e-01, 1.24712103e-01, 4.18588355e-02,
#        3.32974531e-02, 1.97275352e-02, 1.15989292e-02, 1.05849490e-02,
#        9.51987225e-03, 8.20679704e-03, 7.34271766e-03, 6.24992401e-03,
#        5.72876794e-03, 4.99853861e-03, 4.34460690e-03, 3.93751981e-03,
#        3.13932625e-03, 2.77758091e-03, 2.33979116e-03, 2.15553712e-03,
#        1.85576221e-03, 1.66202875e-03, 1.52254552e-03, 1.43028430e-03,
#        1.26702397e-03, 1.17717450e-03, 9.67783650e-04, 9.07102338e-04,
#        8.18280536e-04, 7.80441074e-04, 7.24429809e-04, 7.10169932e-04,
#        6.63573972e-04, 6.38390171e-04, 5.96108461e-04, 5.74928249e-04,
#        4.96152161e-04, 4.61649545e-04, 4.51572775e-04, 4.29098448e-04,
#        4.17738411e-04, 3.87972322e-04, 3.63822380e-04, 3.23664813e-04,
#        3.05204203e-04, 2.94751060e-04, 2.81815832e-04, 2.72480128e-04,
#        2.43175386e-04, 2.16884582e-04, 2.12258712e-04, 2.04991764e-04,
# ...

# %%
pcs.components_
pccomp=pd.DataFrame(pcs.components_)
pccomp
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.119089 -0.036858  0.129027  0.132831  0.102416  0.108774 -0.067557
# 1    0.005571 -0.169940 -0.021118  0.012503  0.004108  0.038127 -0.190403
# 2    0.133677  0.045965  0.015072  0.000451  0.150346 -0.093775 -0.080315
# 3    0.060848  0.086376 -0.061480 -0.049106  0.156742 -0.087300 -0.052371
# 4    0.075426 -0.005368 -0.141082  0.033488  0.108183  0.048809 -0.029716
# 5   -0.032782  0.223139  0.047018  0.116055  0.011725  0.019717  0.033498
# 6   -0.056399  0.136975  0.059378 -0.039860 -0.095430  0.208879  0.010605
# 7    0.013181  0.040101  0.097436 -0.085284 -0.027299 -0.048461  0.028433
# 8    0.034403 -0.031320  0.009766 -0.018181  0.027141 -0.061869  0.018609
# 9   -0.029335 -0.232277  0.064464  0.020708  0.025332  0.089282  0.113302
# 10  -0.007225  0.083183  0.076136 -0.014447 -0.029220 -0.065371  0.032532
# 11  -0.071671 -0.234893  0.078684  0.092897 -0.031082 -0.320613 -0.023528
# ...

# %%
var
# Out:
# array([4.99265283e-01, 1.72695693e-01, 1.24712103e-01, 4.18588355e-02,
#        3.32974531e-02, 1.97275352e-02, 1.15989292e-02, 1.05849490e-02,
#        9.51987225e-03, 8.20679704e-03, 7.34271766e-03, 6.24992401e-03,
#        5.72876794e-03, 4.99853861e-03, 4.34460690e-03, 3.93751981e-03,
#        3.13932625e-03, 2.77758091e-03, 2.33979116e-03, 2.15553712e-03,
#        1.85576221e-03, 1.66202875e-03, 1.52254552e-03, 1.43028430e-03,
#        1.26702397e-03, 1.17717450e-03, 9.67783650e-04, 9.07102338e-04,
#        8.18280536e-04, 7.80441074e-04, 7.24429809e-04, 7.10169932e-04,
#        6.63573972e-04, 6.38390171e-04, 5.96108461e-04, 5.74928249e-04,
#        4.96152161e-04, 4.61649545e-04, 4.51572775e-04, 4.29098448e-04,
#        4.17738411e-04, 3.87972322e-04, 3.63822380e-04, 3.23664813e-04,
#        3.05204203e-04, 2.94751060e-04, 2.81815832e-04, 2.72480128e-04,
#        2.43175386e-04, 2.16884582e-04, 2.12258712e-04, 2.04991764e-04,
# ...

# %%
import numpy as np
cumvar=np.cumsum(np.round(var,decimals=4)*100)
cumvar
# Out:
# array([49.93, 67.2 , 79.67, 83.86, 87.19, 89.16, 90.32, 91.38, 92.33,
#        93.15, 93.88, 94.5 , 95.07, 95.57, 96.  , 96.39, 96.7 , 96.98,
#        97.21, 97.43, 97.62, 97.79, 97.94, 98.08, 98.21, 98.33, 98.43,
#        98.52, 98.6 , 98.68, 98.75, 98.82, 98.89, 98.95, 99.01, 99.07,
#        99.12, 99.17, 99.22, 99.26, 99.3 , 99.34, 99.38, 99.41, 99.44,
#        99.47, 99.5 , 99.53, 99.55, 99.57, 99.59, 99.61, 99.63, 99.65,
#        99.67, 99.69, 99.71, 99.73, 99.74, 99.75, 99.76, 99.77, 99.78,
#        99.79, 99.8 , 99.81, 99.82, 99.83, 99.84, 99.85, 99.86, 99.87,
#        99.88, 99.89, 99.9 , 99.91, 99.92, 99.93, 99.94, 99.95, 99.96,
#        99.97, 99.98, 99.98, 99.98, 99.98, 99.98, 99.98, 99.98, 99.98,
#        99.98, 99.98, 99.98, 99.98, 99.98, 99.98, 99.98, 99.98, 99.98,
#        99.98, 99.98])

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(cumvar)

# %%
pcs=pd.DataFrame(pca_values)
pcs
# Out:
#             0         1         2         3         4         5         6    \
# 0    -10.944151 -8.227907  5.004968  6.512132 -0.608371  4.881661  4.203721
# 1    -11.057649 -7.009317  5.014938  6.111293 -0.701771  4.817620  2.855525
# 2    -10.997664 -7.177644  4.981733  5.922899 -0.406066  4.706959  3.451993
# 3    -10.704587 -7.254298  4.431111  5.477348  0.154616  4.664937  3.216569
# 4    -10.481003 -8.395712  4.530364  5.638388  0.381394  5.001598  3.846025
# 5    -10.388944 -8.830333  4.741420  6.089407  0.182035  4.562077  3.304183
# 6    -10.393818 -8.111527  4.840526  5.698855  0.151488  4.662918  3.275411
# 7    -10.433875 -7.891501  4.652488  5.361751  0.452405  4.516460  2.870018
# 8    -10.275944 -8.390276  4.460049  5.485908  0.514429  4.212513  3.061833
# 9    -10.358826 -8.844652  4.455501  5.569939  0.448652  4.115975  3.064291
# 10   -10.358826 -8.844652  4.455501  5.569939  0.448652  4.115975  3.064291
# ...

# %%
new_def=pd.DataFrame(pca_values[:,:2])

# %%
new_def
# Out:
#               0         1
# 0    -10.944151 -8.227907
# 1    -11.057649 -7.009317
# 2    -10.997664 -7.177644
# 3    -10.704587 -7.254298
# 4    -10.481003 -8.395712
# 5    -10.388944 -8.830333
# 6    -10.393818 -8.111527
# 7    -10.433875 -7.891501
# 8    -10.275944 -8.390276
# 9    -10.358826 -8.844652
# 10   -10.358826 -8.844652
# 11   -10.517532 -8.567330
# 12   -10.519989 -8.643901
# 13   -10.662058 -8.341908
# 14   -10.712071 -8.257028
# 15   -10.947227 -7.425466
# 16   -10.935827 -7.619444
# 17   -10.888950 -7.579198
# 18   -11.034476 -7.611511
# 19   -11.308713 -6.672170
# 20   -11.233083 -7.444844
# 21   -11.155734 -7.792442
# 22   -11.132076 -7.776939
# 23   -11.193567 -7.988304
# 24   -11.343591 -7.917648
# 25   -11.461680 -7.950398
# 26   -11.321692 -8.436585
# 27   -11.409609 -7.650900
# 28   -11.555828 -7.560291
# 29   -11.627594 -6.921945
# ...         ...       ...
# 2970  13.416190 -2.253164
# 2971  13.397681 -2.187435
# 2972  13.461226 -2.224917
# ...

# %%
from sklearn.cluster import KMeans

# %%
m1.fit(new_def)
new_def=new_def.values

# %%
kmeans=KMeans(n_clusters=3)
y_kmeans=kmeans.fit_predict(new_def)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 7.28392185, -0.89064043],
#        [-3.75433943,  3.15831102],
#        [-9.11794548, -5.84661936]])

# %%
kmeans.labels_
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
plt.scatter(new_def[y_kmeans==0,0],new_def[y_kmeans==0,1],s=100,c='red')
plt.scatter(new_def[y_kmeans==1,0],new_def[y_kmeans==1,1],s=100,c='blue')
plt.scatter(new_def[y_kmeans==2,0],new_def[y_kmeans==2,1],s=100,c='green')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='yellow',label='Centroids')
plt.show()

# %%
def cube(y):
    return y*y
cube(2)
# Out:
# 4

# %%
from functools import reduce
li=[]
for i in range(1,100+1):
    li.append(i)
    
v= reduce(lambda x,y :x+y,li)
print(v)
# Out:
# 5050

# %%
count=0
i=0
while(i<100+1):
    count=count+i
    i+=1
print(count)
# Out:
# 5050
