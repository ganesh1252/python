# %% [markdown]
# ### Tasks

# %% [markdown]
# Exercises - 28 May 2019
#
# Print no. of matches won by each team based on year wise (each year as one column)
#
# Print  ManOfMach count of each player in  Hyderabad stadium
#
#  Print number of matches won and loss(as two columns). Consider as win when a team wins Toss  and Match . print for each and every team

# %%
import pandas as pd
df=pd.read_csv("Match.csv")
df
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
df.groupby(['match_winner','match_winner'],axis=1)

# %%
df1=df['match_winner']

# %%
df2=df['Season_Year']
df2.head()
# Out:
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# Name: Season_Year, dtype: int64

# %%
a=pd.concat([df1,df2],axis=1)
a
# Out:
#                     match_winner  Season_Year
# 0          Kolkata Knight Riders         2008
# 1            Chennai Super Kings         2008
# 2               Delhi Daredevils         2008
# 3    Royal Challengers Bangalore         2008
# 4          Kolkata Knight Riders         2008
# 5               Rajasthan Royals         2008
# 6               Delhi Daredevils         2008
# 7            Chennai Super Kings         2008
# 8               Rajasthan Royals         2008
# 9                Kings XI Punjab         2008
# 10              Rajasthan Royals         2008
# 11           Chennai Super Kings         2008
# 12               Deccan Chargers         2008
# 13               Kings XI Punjab         2008
# 14           Chennai Super Kings         2008
# 15                Mumbai Indians         2008
# 16              Delhi Daredevils         2008
# 17               Kings XI Punjab         2008
# 18              Rajasthan Royals         2008
# ...

# %%
d=a.groupby(['match_winner', 'Season_Year']).size().reset_index(name='counts')
d
# Out:
#                    match_winner  Season_Year  counts
# 0           Chennai Super Kings         2008       9
# 1           Chennai Super Kings         2009       8
# 2           Chennai Super Kings         2010       9
# 3           Chennai Super Kings         2011      11
# 4           Chennai Super Kings         2012      10
# 5           Chennai Super Kings         2013      12
# 6           Chennai Super Kings         2014      10
# 7           Chennai Super Kings         2015      10
# 8               Deccan Chargers         2008       2
# 9               Deccan Chargers         2009       9
# 10              Deccan Chargers         2010       8
# 11              Deccan Chargers         2011       6
# 12              Deccan Chargers         2012       4
# 13             Delhi Daredevils         2008       7
# 14             Delhi Daredevils         2009      10
# 15             Delhi Daredevils         2010       7
# 16             Delhi Daredevils         2011       4
# ...

# %%
d.groupby(['match_winner','Season_Year']).size()
# Out:
# match_winner                 Season_Year
# Chennai Super Kings          2008           1
#                              2009           1
#                              2010           1
#                              2011           1
#                              2012           1
#                              2013           1
#                              2014           1
#                              2015           1
# Deccan Chargers              2008           1
#                              2009           1
#                              2010           1
#                              2011           1
#                              2012           1
# Delhi Daredevils             2008           1
#                              2009           1
#                              2010           1
#                              2011           1
#                              2012           1
#                              2013           1
# ...

# %%
df1 = df[(df['City_Name']=='Hyderabad')]
df1
# Out:
#      Match_SK  match_id                Team1                        Team2  \
# 6           6    335993      Deccan Chargers             Delhi Daredevils
# 8           8    335995      Deccan Chargers             Rajasthan Royals
# 17         17    336004      Deccan Chargers              Kings XI Punjab
# 20         20    336007      Deccan Chargers  Royal Challengers Bangalore
# 32         32    336019      Deccan Chargers        Kolkata Knight Riders
# 42         42    336029      Deccan Chargers               Mumbai Indians
# 54         54    336042      Deccan Chargers          Chennai Super Kings
# 176       176    501204      Deccan Chargers             Rajasthan Royals
# 185       185    501213      Deccan Chargers  Royal Challengers Bangalore
# 189       189    501217      Deccan Chargers              Kings XI Punjab
# 200       200    501229      Deccan Chargers               Mumbai Indians
# 215       215    501244      Deccan Chargers        Kolkata Knight Riders
# ...

# %%
df1['ManOfMach'].count()
# Out:
# 41

# %%
win=df1.loc[(df['Toss_Winner'] == df['match_winner'])]
win
# Out:
#      Match_SK  match_id                Team1                    Team2  \
# 8           8    335995      Deccan Chargers         Rajasthan Royals
# 17         17    336004      Deccan Chargers          Kings XI Punjab
# 32         32    336019      Deccan Chargers    Kolkata Knight Riders
# 176       176    501204      Deccan Chargers         Rajasthan Royals
# 189       189    501217      Deccan Chargers          Kings XI Punjab
# 219       219    501248      Deccan Chargers         Delhi Daredevils
# 389       389    598070  Sunrisers Hyderabad         Rajasthan Royals
# 436       436    734012  Sunrisers Hyderabad          Kings XI Punjab
# 504       504    829804  Sunrisers Hyderabad          Kings XI Punjab
# 528       528    980928  Sunrisers Hyderabad           Mumbai Indians
# 534       534    980940  Sunrisers Hyderabad          Kings XI Punjab
# 538       538    980948  Sunrisers Hyderabad  Rising Pune Supergiants
# ...

# %%
loss=df1.loc[(df['Toss_Winner'] != df['match_winner'])]
loss
# Out:
#      Match_SK  match_id                Team1                        Team2  \
# 6           6    335993      Deccan Chargers             Delhi Daredevils
# 20         20    336007      Deccan Chargers  Royal Challengers Bangalore
# 42         42    336029      Deccan Chargers               Mumbai Indians
# 54         54    336042      Deccan Chargers          Chennai Super Kings
# 185       185    501213      Deccan Chargers  Royal Challengers Bangalore
# 200       200    501229      Deccan Chargers               Mumbai Indians
# 215       215    501244      Deccan Chargers        Kolkata Knight Riders
# 226       226    501255      Deccan Chargers                Pune Warriors
# 271       271    548334      Deccan Chargers             Delhi Daredevils
# 299       299    548364      Deccan Chargers              Kings XI Punjab
# 313       313    548378      Deccan Chargers             Rajasthan Royals
# 316       316    548381      Deccan Chargers  Royal Challengers Bangalore
# ...

# %%
w=win['match_winner']
w
# Out:
# 8             Rajasthan Royals
# 17             Kings XI Punjab
# 32       Kolkata Knight Riders
# 176           Rajasthan Royals
# 189            Kings XI Punjab
# 219           Delhi Daredevils
# 389        Sunrisers Hyderabad
# 436            Kings XI Punjab
# 504        Sunrisers Hyderabad
# 528        Sunrisers Hyderabad
# 534        Sunrisers Hyderabad
# 538    Rising Pune Supergiants
# 550        Sunrisers Hyderabad
# 558           Delhi Daredevils
# Name: match_winner, dtype: object

# %%
l=loss['match_winner']

# %%
pd.DataFrame({'win':w,'loss':l})
# Out:
#                          win                         loss
# 6                        NaN             Delhi Daredevils
# 8           Rajasthan Royals                          NaN
# 17           Kings XI Punjab                          NaN
# 20                       NaN  Royal Challengers Bangalore
# 32     Kolkata Knight Riders                          NaN
# 42                       NaN               Mumbai Indians
# 54                       NaN          Chennai Super Kings
# 176         Rajasthan Royals                          NaN
# 185                      NaN              Deccan Chargers
# 189          Kings XI Punjab                          NaN
# 200                      NaN               Mumbai Indians
# 215                      NaN        Kolkata Knight Riders
# 219         Delhi Daredevils                          NaN
# 226                      NaN                Pune Warriors
# 271                      NaN             Delhi Daredevils
# ...
