# %% [markdown]
# ## Get the data set

# %%
import pandas as pd
movie=pd.read_table(r'http://bit.ly/movieusers')
movie.head()
# Out:
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %%
movie=pd.read_table(r'http://bit.ly/movieusers',sep="|",header=None,usecols=[1,3],nrows=4)
movie
# Out:
#     1           3
# 0  24  technician
# 1  53       other
# 2  23      writer
# 3  24  technician

# %% [markdown]
# ## handling missing values

# %% [markdown]
# ## handling missing data using pandas :

# %% [markdown]
#     a.dropna()
#     b.fillna()
#     c.interpolate()

# %%
data.fillna(0)# fill Nan in data replace to 0
# Out:
#     one  two
# 8   0.0  3.0
# 45  1.0  0.0
# 47  0.0  2.0
# 57  0.0  1.0
# 68  2.0  0.0
# 86  3.0  0.0
# 87  0.0  4.0

# %%
data=pd.DataFrame({'beat':['3C','NaN','2A','6C','2A'],'grid':[1115,'NaN',212,0,508]})

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#   beat  grid
# 0   3C  1115
# 1  NaN   NaN
# 2   2A   212
# 3   6C     0
# 4   2A   508

# %%
data.fillna(0)  ## fill missing values
# Out:
#   beat  grid
# 0   3C  1115
# 1  NaN   NaN
# 2   2A   212
# 3   6C     0
# 4   2A   508

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)



df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)


df['four']=df['one']+df['three']
df
# Out:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %%
df.fillna(1)
# Out:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  1.0    4    1.0   1.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.fillna(method="ffill")
# Out:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  3.0    4   30.0  33.0

# %%
df.fillna(method="bfill")
# Out:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %%
df.fillna(method="ffill",axis='columns')
# Out:
#    one  two  three  four
# a  1.0  1.0   10.0  11.0
# b  2.0  2.0   20.0  22.0
# c  3.0  3.0   30.0  33.0
# d  NaN  4.0    4.0   4.0

# %%
df.fillna({'three':'NaN','four':0},inplace=True) ## replace nan with 0
df
# Out:
#    one  two three  four
# a  1.0    1    10  11.0
# b  2.0    2    20  22.0
# c  3.0    3    30  33.0
# d  NaN    4   NaN   0.0

# %% [markdown]
# ### Interpolate() is a function which comes up with a guess based on the other values in the data set

# %%
df.interpolate()
# Out:
#    one  two three  four
# a  1.0    1    10  11.0
# b  2.0    2    20  22.0
# c  3.0    3    30  33.0
# d  3.0    4   NaN   0.0

# %% [markdown]
# ## dropna() is function which will drop rows or columns with missing values

# %% [markdown]
# ## we cant retrive column

# %%
df.dropna()
# Out:
#    one  two three  four
# a  1.0    1    10  11.0
# b  2.0    2    20  22.0
# c  3.0    3    30  33.0

# %%
df
# Out:
#    one  two three  four
# a  1.0    1    10  11.0
# b  2.0    2    20  22.0
# c  3.0    3    30  33.0
# d  NaN    4   NaN   0.0

# %%
df.dropna(how="all") # all drops the rows where all the columns
# Out:
#    one  two three  four
# a  1.0    1    10  11.0
# b  2.0    2    20  22.0
# c  3.0    3    30  33.0
# d  NaN    4   NaN   0.0

# %% [markdown]
# ### Scikit - Learn

# %%
from sklearn.preprocessing import scale

# %% [markdown]
# ### Handling missing values using sickit learn

# %%
from sklearn.preprocessing import Imputer

# %%
imputer=Imputer(missing_values='NaN',strategy="mean",axis=0)
# Out:
# C:\Users\GANESHBABU\Anaconda3\include\New folder\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
df
# Out:
#    one  two three  four
# a  1.0    1    10  11.0
# b  2.0    2    20  22.0
# c  3.0    3    30  33.0
# d  NaN    4   NaN   0.0

# %% [markdown]
# ### Imputation is the process of replacing missing data with substituted values

# %%
im=imputer.fit(movie.iloc[:,1:3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-2f12cb5cb864> in <module>
# ----> 1 im=imputer.fit(movie.iloc[:,1:3])
#
# ~\Anaconda3\include\New folder\lib\site-packages\sklearn\preprocessing\imputation.py in fit(self, X, y)
#     156         if self.axis == 0:
#     157             X = check_array(X, accept_sparse='csc', dtype=np.float64,
# --> 158                             force_all_finite=False)
#     159
#     160             if sparse.issparse(X):
#
# ~\Anaconda3\include\New folder\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# ...

# %%
d = {'one' : pd.Series([1, 2, 3], index=[45,68,86]),
   'two' : pd.Series([1, 2, 3, 4], index=[57,47,8,87,])}

data = pd.DataFrame(d)

# %%
data
# Out:
#     one  two
# 8   NaN  3.0
# 45  1.0  2.5
# 47  NaN  2.0
# 57  NaN  1.0
# 68  2.0  2.5
# 86  3.0  2.5
# 87  NaN  4.0

# %%
im=imputer.fit(data.iloc[:,1:3])

# %%
data.iloc[:,1:2]=im.transform(data.iloc[:,1:2])

# %%
data
# Out:
#     one  two
# 8   NaN  3.0
# 45  1.0  2.5
# 47  NaN  2.0
# 57  NaN  1.0
# 68  2.0  2.5
# 86  3.0  2.5
# 87  NaN  4.0

# %%
data.event.mode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-4f51e3e0fb06> in <module>
# ----> 1 data.event.mode()
#
# ~\Anaconda3\include\New folder\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'event'

# %%
data.event.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-012344c6d9af> in <module>
# ----> 1 data.event.value_counts()
#
# ~\Anaconda3\include\New folder\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'event'

# %%
col=['two']
data[col]=data[col].fillna(data.mode(),iloc[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-b7c1c16df00c> in <module>
#       1 col=['two']
# ----> 2 data[col]=data[col].fillna(data.mode(),iloc[0])
#
# NameError: name 'iloc' is not defined

# %% [markdown]
# ### mean imputation

# %%
data.fillna(data.mean())
# Out:
#     one  two
# 8   2.0  3.0
# 45  1.0  2.5
# 47  2.0  2.0
# 57  2.0  1.0
# 68  2.0  2.5
# 86  3.0  2.5
# 87  2.0  4.0

# %% [markdown]
# ## Median impution

# %%
data.fillna(data.median())
# Out:
#     one  two
# 8   2.0  3.0
# 45  1.0  2.5
# 47  2.0  2.0
# 57  2.0  1.0
# 68  2.0  2.5
# 86  3.0  2.5
# 87  2.0  4.0

# %% [markdown]
# ### Catagerical Data'

# %% [markdown]
#  ## can be handled using pandas with get dummies()

# %%
import pandas as pd
df=pd.read_csv('2 monroe township 2600 550000 
3 monroe township 3000 565000 
4 monroe township 3200 610000 
5 monroe township 3600 680000 
6 monroe township 4000 725000 
7 west windsor 2600 585000 
8 west windsor 2800 615000 
9 west windsor 3300 650000 
10 west windsor 3600 710000 
11 robinsville 2600 575000 
12 robinsville 2900 600000 
13 robinsville 3100 620000 
14 robinsville 3600 695000 
', error_bad_lines=False)
df
# Out:
#   File "<ipython-input-146-ed1f8399dde1>", line 2
#     df=pd.read_csv('2 monroe township 2600 550000
#                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd
df=pd.read_csv(r'homeprices.csv')
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dummy=pd.get_dummies(df)

# %%
dummy
# Out:
#     area   price  town_monroe township  town_robinsville  town_west windsor
# 0   2600  550000                     1                 0                  0
# 1   3000  565000                     1                 0                  0
# 2   3200  610000                     1                 0                  0
# 3   3600  680000                     1                 0                  0
# 4   4000  725000                     1                 0                  0
# 5   2600  585000                     0                 0                  1
# 6   2800  615000                     0                 0                  1
# 7   3300  650000                     0                 0                  1
# 8   3600  710000                     0                 0                  1
# 9   2600  575000                     0                 1                  0
# 10  2900  600000                     0                 1                  0
# ...

# %%
merged=pd.concat([df,dummy],axis=1)

# %%
merged
# Out:
#                town  area   price  area   price  town_monroe township  \
# 0   monroe township  2600  550000  2600  550000                     1
# 1   monroe township  3000  565000  3000  565000                     1
# 2   monroe township  3200  610000  3200  610000                     1
# 3   monroe township  3600  680000  3600  680000                     1
# 4   monroe township  4000  725000  4000  725000                     1
# 5      west windsor  2600  585000  2600  585000                     0
# 6      west windsor  2800  615000  2800  615000                     0
# 7      west windsor  3300  650000  3300  650000                     0
# 8      west windsor  3600  710000  3600  710000                     0
# 9       robinsville  2600  575000  2600  575000                     0
# 10      robinsville  2900  600000  2900  600000                     0
# 11      robinsville  3100  620000  3100  620000                     0
# ...

# %%
a=
